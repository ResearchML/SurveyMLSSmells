# %% [markdown]
# ## This notebook is for the analysis of the survey data that study the challenges and common practices of the developers to develop ML applications

# %%
import pandas as pd
import numpy as np
import os
import pathlib
import plotly.graph_objects as go
from IPython.display import Markdown, display
import plotly.express as px

# %%
def printmd(string):
    display(Markdown(string))

# %%
path_root = os.path.dirname(os.getcwd())
data_path = os.path.join(path_root,'data', 'all-cleaned-data.csv')
print(data_path)
# Out:
# C:\Users\C5265284\PycharmProjects\MLS-survey\data\all-cleaned-data.csv

# %%
data_df= pd.read_csv(data_path)
data_df.head(5)
# Out:
#   Keep Survey Type     System role_rganization  years_experience  \
# 0  Yes      Open_1  None-Open        Developer  1 year - 5 Years
# 1  Yes      Open_1  None-Open        Team Lead  1 year - 5 Years
# 2  Yes      Open_1  None-Open        Developer        5-10 Years
# 3  Yes      Open_1  None-Open  Project Manager        5-10 Years
# 4  Yes      Open_1  None-Open       QA Manager  1 year - 5 Years
#
#                                 domain_activity Python_experience  \
# 0  Analytics (Business,IT services, BigData...)       Comfortable
# 1  Analytics (Business,IT services, BigData...)            Expert
# 2                         Other, please specify  Little Knowledge
# 3                 Robotics and Embeeded systems            Expert
# 4                      Research and development       Comfortable
#
#   Cpp_experience Java_experience C_experience  ... Smell13_Refactoring  \
# 0         Expert       Practical  Comfortable  ...                 NaN
# ...

# %%
cols=data_df.columns
print(cols[0:100])
# Out:
# Index(['Keep', 'Survey Type', 'System', 'role_rganization', 'years_experience',
#        'domain_activity', 'Python_experience', 'Cpp_experience',
#        'Java_experience', 'C_experience', 'C#_experience',
#        'NotHandlingExceptions_prevalence',
#        'AssumingSafeReturnValue_prevalence',
#        'ExcessiveCommunication_prevalence', 'Clustering_prevalence',
#        'Scattering_prevalence', 'HardCodingLibraries_prevalence',
#        'LocalReferences_prevalence', 'MemoryManagement_prevalence',
#        'CachingObjects_prevalence', 'SecuringLibraries_prevalence',
#        'RelativePath_prevalence', 'ExcessiveObjects_prevalence',
#        'UnusedDeclaration_prevalence', 'UnusedImplementation_prevalence',
#        'UnusedParameters_prevalence', 'NotHandlingExceptions_Expandability',
#        'NotHandlingExceptions_Simplicity', 'NotHandlingExceptions_Reusability',
#        'NotHandlingExceptions_Learnability',
#        'NotHandlingExceptions_Understandability',
# ...

# %%
def get_unique_values (data_df, col : str):
    values = data_df[col].values
    value_list =[]
    for x in values:
#        v_list = x.split(';')
       value_list.extend([x]) 
    unique_val = set(value_list)
    return unique_val

# %%
def replace_substring(org_str, str_to_rep, rep_with):
    org_str =org_str.upper().replace(str_to_rep.upper(),rep_with)
    return org_str

# %%
def get_item_stats(data_df, col):
    unique_vals = get_unique_values(data_df,col)
    unq_vals = list(unique_vals)
    counter = [0 for i in range(len(unq_vals))]

    print(unq_vals)

    for i in range(len(unq_vals)):
        count = 0
        for j in range (len(df_vals)):
            if unq_vals[i] in df_vals[j]:
                count= count+1;
        counter[i] = count
    return unq_vals, counter

# %%
col = 'role_rganization'
fig_path = os.path.join(path_root,'figures', col +'.pdf')
df_vals = data_df[col].map(lambda x: x if x not in ['Other, please specify'] else 'Other')
data_df[col]= df_vals

v_count = data_df[col].value_counts()
print(v_count)

lbls = list(v_count.index)
vals = list(v_count)

print(list(v_count.index))

fig = go.Figure()
fig = go.Figure(data=[go.Pie(labels=lbls, values=vals, textinfo='label+value+percent',name ='Organization Type') ])

fig.show()
# print(fig_path)
fig.write_image(fig_path)
# Out:
# Software Engineer    40
# Developer            28
# Team Lead            16
# Project Manager      14
# Architect            11
# Tester                8
# Other                 6
# QA Manager            5
# Self-employed         4
# Name: role_rganization, dtype: int64
# ['Software Engineer', 'Developer', 'Team Lead', 'Project Manager', 'Architect', 'Tester', 'Other', 'QA Manager', 'Self-employed']
# <div>
#
#
#             <div id="e4c9ec71-bc5a-4375-a80d-daed6ecf9ac8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e4c9ec71-bc5a-4375-a80d-daed6ecf9ac8")) {
#                     Plotly.newPlot(
#                         'e4c9ec71-bc5a-4375-a80d-daed6ecf9ac8',
# ...

# %%
col = 'years_experience'
fig_path = os.path.join(path_root,'figures', col +'.pdf')
# df_vals = data_df[col].map(lambda x: x if x not in ['Other, please specify'] else 'Other')
# data_df[col]= df_vals

v_count = data_df[col].value_counts()
print(v_count)

lbls = list(v_count.index)
vals = list(v_count)

print(list(v_count.index))

fig = go.Figure()
fig = go.Figure(data=[go.Pie(labels=lbls, values=vals, textinfo='label+value+percent',name ='Organization Type') ])

fig.show()
# print(fig_path)
fig.write_image(fig_path)
# Out:
# 5-10 Years            57
# More than 10 years    43
# 1 year - 5 Years      30
# Less than 1 year       2
# Name: years_experience, dtype: int64
# ['5-10 Years', 'More than 10 years', '1 year - 5 Years', 'Less than 1 year']
# <div>
#
#
#             <div id="cd0449df-f394-4c38-aa90-a811387805ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cd0449df-f394-4c38-aa90-a811387805ff")) {
#                     Plotly.newPlot(
#                         'cd0449df-f394-4c38-aa90-a811387805ff',
#                         [{"labels": ["5-10 Years", "More than 10 years", "1 year - 5 Years", "Less than 1 year"], "name": "Organization Type", "textinfo": "label+value+percent", "type": "pie", "values": [57, 43, 30, 2]}],
# ...

# %%
col = 'domain_activity'
fig_path = os.path.join(path_root,'figures', col +'.pdf')
df_vals = data_df[col].map(lambda x: x if x not in ['Other, please specify'] else 'Other')
data_df[col]= df_vals

v_count = data_df[col].value_counts()
print(v_count)

lbls = list(v_count.index)
vals = list(v_count)

print(list(v_count.index))

fig = go.Figure()
fig = go.Figure(data=[go.Pie(labels=lbls, values=vals, textinfo='label+value+percent',name ='Organization Type') ])

fig.show()
# print(fig_path)
fig.write_image(fig_path)
# Out:
# Research and development                        38
# Analytics (Business,IT services, BigData...)    25
# Games                                           18
# Networks                                        18
# Robotics and Embeeded systems                   17
# Other                                            9
# Banking and insurance                            7
# Name: domain_activity, dtype: int64
# ['Research and development', 'Analytics (Business,IT services, BigData...)', 'Games', 'Networks', 'Robotics and Embeeded systems', 'Other', 'Banking and insurance']
# <div>
#
#
#             <div id="7c75d780-b17e-4216-a85b-3a22a738c12d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7c75d780-b17e-4216-a85b-3a22a738c12d")) {
# ...

# %%
col = 'Python_experience'
fig_path = os.path.join(path_root,'figures', col +'.pdf')
# df_vals = data_df[col].map(lambda x: x if x not in ['Other, please specify'] else 'Other')
# data_df[col]= df_vals

v_count = data_df[col].value_counts()
print(v_count)

lbls = list(v_count.index)
vals = list(v_count)

print(list(v_count.index))

fig = go.Figure()
fig = go.Figure(data=[go.Pie(labels=lbls, values=vals, textinfo='label+value+percent',name ='Organization Type') ])

fig.show()
# print(fig_path)
fig.write_image(fig_path)
# Out:
# Expert              42
# Comfortable         37
# Practical           30
# Little Knowledge    18
# Novice               5
# Name: Python_experience, dtype: int64
# ['Expert', 'Comfortable', 'Practical', 'Little Knowledge', 'Novice']
# <div>
#
#
#             <div id="80ae5024-3aa6-4c01-baff-8681b79d32bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("80ae5024-3aa6-4c01-baff-8681b79d32bb")) {
#                     Plotly.newPlot(
#                         '80ae5024-3aa6-4c01-baff-8681b79d32bb',
#                         [{"labels": ["Expert", "Comfortable", "Practical", "Little Knowledge", "Novice"], "name": "Organization Type", "textinfo": "label+value+percent", "type": "pie", "values": [42, 37, 30, 18, 5]}],
# ...

# %%
data = pd.DataFrame()
val_list =['Business Intelligence', 'Healthcare', 'Security', 'Communications', 'Educational Software', 'Games and Multimedia', 
           'E-commerce', 'Finance and Revenue Management', 'Environment Data Analysis and Forecasting', 'Computer Vision', 'Speech Processing', 
           'Autonomous Systems', 'Social Network Analytics', 'Document Analysis', 'Research and Development', 'Other']

val_count =[29, 9, 7, 6, 7, 12, 5, 6, 9, 2, 2, 2, 4, 20, 4, 5]
data['Application Types'] = val_list
data['Count'] = val_count
fig = px.bar(data, y='Application Types', x='Count',text=val_count, orientation ='h', height =450, width=650) #,text=val_list
fig.show()
# Out:
# <div>
#
#
#             <div id="2864734b-ae3b-415a-b339-65a685592df9" class="plotly-graph-div" style="height:450px; width:650px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2864734b-ae3b-415a-b339-65a685592df9")) {
#                     Plotly.newPlot(
#                         '2864734b-ae3b-415a-b339-65a685592df9',
# ...

# %%
col = 'Python_experience'
values = data_df[col].values


# df_vals = cleaned_df[col].map(lambda x: x if x not in ['None'] else 'Others')
# cleaned_df[col]= df_vals

print(values)
val_unique = get_unique_values(data_df, col)

print(val_unique)


val_list, val_count = get_item_stats(data_df, col)


data = pd.DataFrame()
data['Experience Level'] = val_list
data['Count'] = val_count
fig = px.bar(data, x='Experience Level', y='Count')
fig.show()
# Out:
# ['Comfortable' 'Expert' 'Little Knowledge' 'Expert' 'Comfortable'
#  'Little Knowledge' 'Expert' 'Comfortable' 'Comfortable' 'Expert'
#  'Comfortable' 'Expert' 'Practical' 'Expert' 'Comfortable' 'Novice'
#  'Expert' 'Comfortable' 'Little Knowledge' 'Practical' 'Expert' 'Novice'
#  'Comfortable' 'Comfortable' 'Comfortable' 'Expert' 'Practical' 'Expert'
#  'Expert' 'Practical' 'Novice' 'Expert' 'Little Knowledge' 'Comfortable'
#  'Expert' 'Practical' 'Practical' 'Expert' 'Practical' 'Comfortable'
#  'Expert' 'Novice' 'Little Knowledge' 'Practical' 'Comfortable'
#  'Practical' 'Comfortable' 'Expert' 'Comfortable' 'Comfortable'
#  'Little Knowledge' 'Expert' 'Expert' 'Expert' 'Practical'
#  'Little Knowledge' 'Comfortable' 'Expert' 'Expert' 'Expert' 'Expert'
#  'Comfortable' 'Expert' 'Little Knowledge' 'Practical' 'Practical'
#  'Comfortable' 'Expert' 'Expert' 'Little Knowledge' 'Practical'
#  'Comfortable' 'Little Knowledge' 'Practical' 'Practical' 'Practical'
# ...

# %%
col = 'P1S1Q3'
values = cleaned_df[col].values
printmd('**'+ques_dict[col]+'**')
print()

df_vals = cleaned_df[col].map(lambda x: x if x not in ['None'] else 'Others')
cleaned_df[col]= df_vals

val_unique = get_unique_values(cleaned_df,col)

print(val_unique)


val_list, val_count = get_item_stats(cleaned_df, col)
printmd('**'+ques_dict[col]+'**')

data = pd.DataFrame()
data['Application Domain'] = val_list
data['Count'] = val_count
fig = px.bar(data, x='Application Domain', y='Count')
fig.show()
# Out:
# **Q3. What ML domains are associated with the applications developed in your organization?**
# {'Clustering', 'recommendation, regression', 'Animation, Rendering and gameplay AI', 'reinforcement learning', 'multi-armed bandits and reinforcement learning', 'Video Processing', 'Image Processing', 'Biomedical engineering', 'none', 'Speech Processing', 'Anomaly Detection', 'Reinforcement learning', 'Natural Language Processing', 'Control', 'music generation', 'Predictive analytics', 'Optimization ', 'I have mentioned all that I want to work in.'}
# ...

# %% [markdown]
# * Image Processing (45)
#
# * Video Processing (20)
#
# * Natural language Processing (44)
#
# * predictive analytics (37) + recommendation, regression (1) = 38
#
# * Clustering (31)
#
# * Speech Processing (12)
#
# * Reinforcement Learning (1 + 1) + multi-arm bandit and RL (1) = 3
#
# * Optimization (1)
#
# * Music generation (1)
#
# * Anomaly detection (1)
#
# * Animation, Rendering, Game play (1) = 1
#
# * Control (1) + Biomedical engineering(1) = 2
#
# * Others: None(1) + I have mentioned (1) = 2

# %%
data = pd.DataFrame()
val_list =['Image Processing','Video Processing','Natural language Processing', 'Clustering', 
           'Speech Processing and Audio Processing', 'Predictive Analytics and Recommendations',  
            'Reinforcement Learning', 'Others']


val_count =[45, 20, 44, 31, 13, 38, 3, 5]
data['ML Domains of Expertise'] = val_list
data['Count'] = val_count
fig = px.bar(data, y='ML Domains of Expertise', x='Count',text=val_count, orientation ='h', height =300, width=600) #,text=val_list
fig.show()
# Out:
# <div>
#
#
#             <div id="6f1878c6-22f7-46db-aa19-8d332abf38a3" class="plotly-graph-div" style="height:300px; width:600px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6f1878c6-22f7-46db-aa19-8d332abf38a3")) {
#                     Plotly.newPlot(
#                         '6f1878c6-22f7-46db-aa19-8d332abf38a3',
# ...

# %%
col = 'P1S1Q4'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# unique_vals = get_unique_values(cleaned_df,col)

vals = list(v_count)
# lbls = list(v_count.index)
# print(list(v_count.index))
# fig = go.Figure(data=[go.Bar(labels=lbls, values=vals)])
# fig.show()


val_count = list(v_count)
val_list = list(v_count.index)
for x in val_list:
    print(x)

data = pd.DataFrame()
data['Development Methodology'] = val_list
data['Count'] = val_count
fig = px.bar(data, x='Development Methodology', y='Count')
fig.show()
# Out:
# **Q4. What software development process (e.g.,  agile methodology SCRUM) is used to develop ML applications in your organization?**
# Agile
# SCRUM
# agile
# None
# Jira
# Scrum
# Lean
# Agile SCRUM
# Kanban
# Not Applicable
# none
# -
# not a solid SDP but more like agile
# None in specific
# Nothing specific
# Loosely organized agile
# Agile is not working well for applied R&D
# SCRUM + CRISP-DM
# No framework
# unit testing, integration testing, devops (continuous integration and delivery), feature driven
# LEAN
# No particular process
# ...

# %% [markdown]
# * Agile= 11+ + 4+ 7+ +2 +2 +2 +2 +2+20= 52
# * No specific= 4+ +2 + 1 + 1 +1 +1 +1 +1 +1 +1 = 18
# * Others = 10

# %%
val_count = [52,18,10]
val_list = ['Agile', 'No Specific Methodology', 'Others']
fig = go.Figure()
fig = go.Figure(data=[go.Pie(labels=val_list, values=val_count, textinfo='label+value+percent',name ='Development Methodology') ])
#marker_colors=['rgb(146, 123, 21)', 'rgb(177, 180, 34)', 'rgb(206, 206, 40)','rgb(175, 51, 21)', 'rgb(35, 36, 21)'])]
fig.show()
# Out:
# <div>
#
#
#             <div id="aa4f51cf-b98e-486d-a19d-35b39e9fd8a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("aa4f51cf-b98e-486d-a19d-35b39e9fd8a5")) {
#                     Plotly.newPlot(
#                         'aa4f51cf-b98e-486d-a19d-35b39e9fd8a5',
#                         [{"labels": ["Agile", "No Specific Methodology", "Others"], "name": "Development Methodology", "textinfo": "label+value+percent", "type": "pie", "values": [52, 18, 10]}],
# ...

# %%
col = 'P1S2Q1'
v_count = cleaned_df[col].value_counts()
printmd('**'+ques_dict[col]+'**')
print()
print(v_count)
print(list(v_count.index))
lbls = list(v_count.index)
vals = list(v_count)
fig = go.Figure(data=[go.Pie(labels=lbls, values=vals)])
fig.show()
# Out:
# **Q1. How long have you been working in software development?**
# 5 Years or more     35
# 2 Years             19
# Less than 1 year     9
# 3 Years              9
# 4 years              8
# Name: P1S2Q1, dtype: int64
# ['5 Years or more', '2 Years', 'Less than 1 year', '3 Years', '4 years']
# <div>
#
#
#             <div id="ad3f99f8-a16f-4124-9efe-802151220e83" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ad3f99f8-a16f-4124-9efe-802151220e83")) {
#                     Plotly.newPlot(
#                         'ad3f99f8-a16f-4124-9efe-802151220e83',
#                         [{"labels": ["5 Years or more", "2 Years", "Less than 1 year", "3 Years", "4 years"], "type": "pie", "values": [35, 19, 9, 9, 8]}],
# ...

# %%
lbls = ['5 Years or more','4 Years','3 Years','2 Years', '1 Year or less']
vals = [35,8,9,19,9]
fig = go.Figure(data=[go.Pie(labels=lbls, values=vals, textinfo='label+value+percent')])
fig.show()
# Out:
# <div>
#
#
#             <div id="49a7ce8c-a0b3-4fb2-9caa-90b900c330b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("49a7ce8c-a0b3-4fb2-9caa-90b900c330b5")) {
#                     Plotly.newPlot(
#                         '49a7ce8c-a0b3-4fb2-9caa-90b900c330b5',
#                         [{"labels": ["5 Years or more", "4 Years", "3 Years", "2 Years", "1 Year or less"], "textinfo": "label+value+percent", "type": "pie", "values": [35, 8, 9, 19, 9]}],
# ...

# %%
col = 'P1S2Q2'
v_count = cleaned_df[col].value_counts()
printmd('**'+ques_dict[col]+'**')
print()
print(v_count)
print(list(v_count.index))
lbls = list(v_count.index)
vals = list(v_count)
fig = go.Figure(data=[go.Pie(labels=lbls, values=vals)])
fig.show()
# Out:
# **Q2. How long have you been working on ML application development?**
# 2 Years             30
# Less than 1 year    14
# 5 Years or more     13
# 3 Years             12
# 4 years             11
# Name: P1S2Q2, dtype: int64
# ['2 Years', 'Less than 1 year', '5 Years or more', '3 Years', '4 years']
# <div>
#
#
#             <div id="fe5f6b8a-c938-4a13-83a8-e81bb62354a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fe5f6b8a-c938-4a13-83a8-e81bb62354a3")) {
#                     Plotly.newPlot(
#                         'fe5f6b8a-c938-4a13-83a8-e81bb62354a3',
#                         [{"labels": ["2 Years", "Less than 1 year", "5 Years or more", "3 Years", "4 years"], "type": "pie", "values": [30, 14, 13, 12, 11]}],
# ...

# %%
lbls = ['5 Years or more','4 Years','3 Years','2 Years', '1 Year or less']
vals = [13,11,12,30,14]
fig = go.Figure(data=[go.Pie(labels=lbls, values=vals, textinfo='label+value+percent')])
fig.show()
# Out:
# <div>
#
#
#             <div id="9e0974ce-2e4d-418d-bc77-5eaa7abfffe6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9e0974ce-2e4d-418d-bc77-5eaa7abfffe6")) {
#                     Plotly.newPlot(
#                         '9e0974ce-2e4d-418d-bc77-5eaa7abfffe6',
#                         [{"labels": ["5 Years or more", "4 Years", "3 Years", "2 Years", "1 Year or less"], "textinfo": "label+value+percent", "type": "pie", "values": [13, 11, 12, 30, 14]}],
# ...

# %%
col = 'P1S2Q3'
printmd('**'+ques_dict[col]+'**')
print()

df_vals = cleaned_df[col].map(lambda x: x if x not in ['high school'] else 'Other')
cleaned_df[col]= df_vals

v_count = cleaned_df[col].value_counts()
print(v_count)
print(list(v_count.index))
lbls = list(v_count.index)
vals = list(v_count)
fig = go.Figure(data=[go.Pie(labels=lbls, values=vals)])
fig.show()
# Out:
# **Q3. What is your highest level of education or training?**
# Masters                                32
# Bachelor                               29
# PhD or above                           16
# Other                                   1
# I am fourth year bachelors student.     1
# Starting Master's in January            1
# Name: P1S2Q3, dtype: int64
# ['Masters', 'Bachelor', 'PhD or above', 'Other', 'I am fourth year bachelors student.', "Starting Master's in January"]
# <div>
#
#
#             <div id="27c3c907-80bb-483e-8109-bdd94880ad00" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("27c3c907-80bb-483e-8109-bdd94880ad00")) {
#                     Plotly.newPlot(
#                         '27c3c907-80bb-483e-8109-bdd94880ad00',
# ...

# %%
lbls = ['Masters','Bachelor','PhD','Other']
vals = [32,31,16,1]
fig = go.Figure(data=[go.Pie(labels=lbls, values=vals, textinfo='label+value+percent')])
fig.show()
# Out:
# <div>
#
#
#             <div id="5bbe98d5-c24b-4fd7-81da-151c96760279" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5bbe98d5-c24b-4fd7-81da-151c96760279")) {
#                     Plotly.newPlot(
#                         '5bbe98d5-c24b-4fd7-81da-151c96760279',
#                         [{"labels": ["Masters", "Bachelor", "PhD", "Other"], "textinfo": "label+value+percent", "type": "pie", "values": [32, 31, 16, 1]}],
# ...

# %%
col = 'P1S2Q4'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(list(v_count.index))

df_vals = cleaned_df[col].map(lambda x: replace_substring(x,"SCALA", 'SCALA') if len(x)>0 else x)
cleaned_df[col]= df_vals

val_list, val_count = get_item_stats(cleaned_df, col)
# Out:
# **Q4. What programming language(s) do you use for machine learning ?**
# ['SCALA', 'PYTHON', 'JAVA', 'C#', 'MATLAB', 'C++', 'JAVASCRIPT', 'STAN', 'CLOJURE', 'NODE JS', 'R', 'CUDA AND COMPUTE SHADERS']

# %%
printmd('**'+ques_dict[col]+'**')

data = pd.DataFrame()
data['Language'] = val_list
data['Count'] = val_count
print(val_list)
print(val_count)
fig = px.bar(data, x='Language', y='Count')
fig.show()
# Out:
# **Q4. What programming language(s) do you use for machine learning ?**
# ['SCALA', 'PYTHON', 'JAVA', 'C#', 'MATLAB', 'C++', 'JAVASCRIPT', 'STAN', 'CLOJURE', 'NODE JS', 'R', 'CUDA AND COMPUTE SHADERS']
# [6, 77, 10, 2, 8, 16, 1, 1, 1, 1, 11, 1]
# <div>
#
#
#             <div id="e7fa1334-60c5-4c3b-aeae-c85bc2d54075" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e7fa1334-60c5-4c3b-aeae-c85bc2d54075")) {
#                     Plotly.newPlot(
#                         'e7fa1334-60c5-4c3b-aeae-c85bc2d54075',
# ...

# %%
data = pd.DataFrame()
val_list =['C++', 'SCALA', 'JAVA', 'R', 'PYTHON', 'CLOJURE', 'STAN', 'NODE JS', 'C#', 'JAVASCRIPT',
           'CUDA', 'MATLAB']
val_count =[16, 6, 10, 11, 77, 1, 1, 1, 2, 1, 1, 8]
data['Language'] = val_list
data['Count'] = val_count
fig = px.bar(data, y='Language', x='Count',text=val_count, orientation ='h', height =400, width=600) #,text=val_list
fig.show()
# Out:
# <div>
#
#
#             <div id="7b58c3d7-4021-4c5b-be92-8e645fcf4d07" class="plotly-graph-div" style="height:400px; width:600px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7b58c3d7-4021-4c5b-be92-8e645fcf4d07")) {
#                     Plotly.newPlot(
#                         '7b58c3d7-4021-4c5b-be92-8e645fcf4d07',
# ...

# %%
def get_item_stats(data_df, col):
    df_vals = data_df[col].values
    unique_vals = get_unique_values(cleaned_df,col)
    unq_vals = list(unique_vals)
    counter = [0 for i in range(len(unq_vals))]

#     print(unq_vals)

    for i in range(len(unq_vals)):
        count = 0
        for j in range (len(df_vals)):
            if unq_vals[i] in df_vals[j]:
                count= count+1;
        counter[i] = count
    return unq_vals, counter

# %%
col = 'P1S2Q5'
printmd('**'+ques_dict[col]+'**')
print()
v_count = cleaned_df[col].value_counts()
# print(v_count)

val_list, val_count = get_item_stats(cleaned_df, col)

print(val_list)
print(val_count)
data = pd.DataFrame()
data['MLFramework'] = val_list
data['Count'] = val_count
fig = px.bar(data, x='MLFramework', y='Count')
fig.show()
# Out:
# **Q5. What framework(s) do you use for machine learning?**
# ['Xgboost', 'Scikit-Learn', 'scikit-learn, mllib', 'SK Learn (Python)', 'MXNet', 'Chainer', 'Caret', 'OpenCV', 'Keras', 'Tensorflow.js', 'vowpal wabbit', 'PyTorch', 'Deeplearning4j', 'scikit', 'ML.NET', 'Caffe', 'TensorFlow']
# [1, 1, 1, 1, 9, 2, 1, 1, 44, 1, 1, 53, 3, 2, 1, 4, 58]
# <div>
#
#
#             <div id="7e18ec82-9753-4d52-a143-91296b4b4da1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7e18ec82-9753-4d52-a143-91296b4b4da1")) {
#                     Plotly.newPlot(
#                         '7e18ec82-9753-4d52-a143-91296b4b4da1',
# ...

# %%
data = pd.DataFrame()
val_list =['Scikit-learn','TensorFlow', 'Keras', 'Caffe', 'MXNet', 'PyTorch', 'Deeplearning4j','Chainer', 'Others']
val_count =[5, 58, 44, 4, 9, 53, 3, 2, 7]
data['ML Framework'] = val_list
data['Count'] = val_count
fig = px.bar(data, y='ML Framework', x='Count',text=val_count, orientation ='h', height =400, width=600) #,text=val_list
fig.show()
# Out:
# <div>
#
#
#             <div id="aa28b097-ed3a-42d9-99ae-65de48bb2182" class="plotly-graph-div" style="height:400px; width:600px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("aa28b097-ed3a-42d9-99ae-65de48bb2182")) {
#                     Plotly.newPlot(
#                         'aa28b097-ed3a-42d9-99ae-65de48bb2182',
# ...

# %%
col = 'P1S2Q6'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
print(v_count.index)

val_list, val_count = get_item_stats(cleaned_df, col)

print(val_list)
print(val_count)
data = pd.DataFrame()
data['Job Title'] = val_list
data['Count'] = val_count
fig = px.bar(data, x='Job Title', y='Count')
fig.show()
# Out:
# **Q6. What is your job title?**
# Index(['AI/ML Engineer', 'Data Scientist', 'AI/ML Researcher/Scientist',
#        'AI/ML Developer', 'Full Stack Developer', 'Student', 'Data Engineer',
#        'PhD Student of Computer Science', 'Software Engineer',
#        'Chief AI Officer', 'Developer/Business Analyst', 'Research Associate',
#        'PhD Student', 'Student at Data Science Group',
#        'I am doing my bachelors majoring in Information Technology and Mathematics. Currently, I am in my fourth year.',
#        'SDE intern', 'Master student', 'Researcher', 'ML Software Architect',
#        'Research Software Engineer', 'Software Team Lead',
#        'Independant Researcher', 'Not Applicable', 'DL Manager'],
#       dtype='object')
# ...

# %% [markdown]
# * Researcher (12) + Research Associate (1) + Independent Rsearcher (1) = 14
#
# * AI/ML Rsearch Scientist (10)
#
# * AI/ML Engineer (24) + Software Engineer (2)
#
# * Data Scientist (18)
#
# * AI/ML Developer (5) + Developer/Business Analyst (1) + Fullstack developer (3)
#
# * ML Software Architect (1)
#
# * Phd Student (2+1) + Masters (1) + Student (1) + Student DS (1)
#
# * SDE Intern (1) +
#
# * Software Team Lead (1)
#
# * DL Manager (1)
#
# * Cheif AI Officier (1)

# %%
data = pd.DataFrame()
val_list =['AI/ML engineer', 'Data Scientist', 'Researchers', 'ML Developer-Analyst', 'Interns', 'Upper Level Managers', 'Students']
val_count =[26, 18, 24, 9, 1, 4, 6]
data['Job Titles'] = val_list
data['Count'] = val_count
fig = px.bar(data, y='Job Titles', x='Count',text=val_count, orientation ='h', height =300, width=650) #,text=val_list
# fig.update_traces(textfont_size=14)
# fig.update_layout(textfont_size=14)

# fig = go.Figure()

# fig.add_trace(go.Bar(
#     x=val_list,
#     y=val_count,
# #     name="Name of Trace 1"       # this sets its legend entry
# ))


# fig.update_layout(
#     xaxis_title="Job Titles/Roles",
#     yaxis_title="Count",
#     font=dict(size=10)
# )
fig.show()
# Out:
# <div>
#
#
#             <div id="1572a42f-a9b8-49fb-b16a-95f6aa929b6f" class="plotly-graph-div" style="height:300px; width:650px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1572a42f-a9b8-49fb-b16a-95f6aa929b6f")) {
#                     Plotly.newPlot(
#                         '1572a42f-a9b8-49fb-b16a-95f6aa929b6f',
# ...

# %%
col = 'P1S2Q7'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(v_count.index)
resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
    
# val_list, val_count = get_item_stats(cleaned_df, col)

# print(val_list)
# print(val_count)
# data = pd.DataFrame()
# data['Job Title'] = val_list
# data['Count'] = val_count
# fig = px.bar(data, x='Job Title', y='Count')
# fig.show()
# Out:
# **Q7. Please briefly list your key job responsibilities.**
# 1: Not Applicable
# 2: research/develop ML methods/applications
# 3: Implementation for research.
# 4: Design ML systems architecture, data collection and processing, design and testing of algorithms
# 5: Learning
# 6: Developing ML algorithms for Medical Image Analysis
# 7: I conduct network and NLP related analysis on the art market
# 8: Maintain and develop methods for private machine learning
# 9: Building models for language understanding and image understanding.
# Building RESTful APIs to export interfaces for downstream tasks so that they can use my models.
# 10: 1. Release BERT-Bahasa and XLNET-Bahasa pretrained model to help Applied Bahasa NLP follow current NLP SOTA.
# 1. Serving multiple APIs using Kong with complete authentication gateway for developers with ease and deploy scalable Tensorflow deployments on Google Kubernetes Engine.
# ...

# %%
col = 'P2S1Q1'
printmd('**'+ques_dict[col]+'**')
print()

# print(cleaned_df[col])
v_count = cleaned_df[col].value_counts()
# print(v_count.index)
resp_list = []
resp_set =[]
resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
    resps = resp[i].split(';')
    resp_list.append(resps)
    resp_set.extend(resps)

values = list(cleaned_df[col].values)
# print(type(values))

# print(resp_list)
# print(resp_set)
all_resp = list(set(resp_set))
# print(all_resp)
    
resp_count = []
for i in range (len(all_resp)):
    resp_count.extend([0])

valid = 0
for i in range (len(all_resp)):    
    count = 0
    for j in range(len(values)):
        if str(values[j])!='nan':
            if i == 0:
                valid= valid +1
            if str(all_resp[i]) in str(values[j]).split(';'):
                count =count+1
    resp_count[i]= count

print(resp_count)
print(valid)

data = pd.DataFrame()
data['Data Source'] = all_resp
data['Count'] = resp_count
fig = px.bar(data, x='Data Source', y='Count')
fig.show()
# Out:
# **Q1. What are the primary source(s) of data for Machine Learning in your organization? Please check all applicable.**
# 1: Open datasets;Internal company data
# 2: Open datasets
# 3: Internal company data
# 4: Open datasets;Internal company data;Data from third-party clients
# 5: Open datasets;Data from third-party clients
# 6: Data from third-party clients
# 7: Internal company data;Data from third-party clients
# 8: Data from third-party clients;Webcrawling
# 9: Open datasets;Arxiv, Kaggle
# 10: Open datasets;I create datasets based on the problem I’m looking to solve. I let my problem decide the dataset, and vice versa
# [1, 1, 35, 31, 15, 1]
# 49
# <div>
#
#
#             <div id="88cd75b3-a1d0-454b-b52b-0b85b8dc98a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
# ...

# %%
data = pd.DataFrame()
val_list =['Open Datasets','Internal Company Data', 'Data From Third-party Client', 'Other']
val_count =[36, 31, 15, 2]
data['ML Data Source'] = val_list
data['Count'] = val_count
fig = px.bar(data, y='ML Data Source', x='Count',text=val_count, orientation ='h', height =300, width=600) #,text=val_list
fig.show()
# Out:
# <div>
#
#
#             <div id="123dbc2a-5ff2-4cb6-b052-810823d372da" class="plotly-graph-div" style="height:300px; width:600px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("123dbc2a-5ff2-4cb6-b052-810823d372da")) {
#                     Plotly.newPlot(
#                         '123dbc2a-5ff2-4cb6-b052-810823d372da',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Count=%{x}<br>ML Data Source=%{y}<br>text=%{text}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "h", "showlegend": false, "text": [36.0, 31.0, 15.0, 2.0], "textposition": "auto", "type": "bar", "x": [36, 31, 15, 2], "xaxis": "x", "y": ["Open Datasets", "Internal Company Data", "Data From Third-party Client", "Other"], "yaxis": "y"}],
# ...

# %%
col = 'P2S1Q2'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(v_count.index)
resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
# Out:
# **Q2. Once you have raw data, how do you test the quality of the data?**
# 1: statistical validation
# 2: Plotting
# 3: Set up queries and analyze the data for any missing information or inconsistencies.
# 4: Descriptive Analysis & Clustering
# 5: Sanity checks like duplicates, missing values, compare with expectations of domain experts
# 6: notebook with basic data exploration
# 7: I asses based on my business needs. If it doesn't qualify, usually, internal company data is required
# 8: In general, I look for empty cells, mismatching formats (e.g., string value into integer column, duplicate primary key, ),  inconsistency (e.g., negative age), understand the reasons for outliers (e.g., could have an error in the capture?),  try to understand the model errors (e.g., data mislabelling).
# 9: Rely on public datasets used in previous research projects
# 10: By checking the size of dataset, the number of missed data, the number of out layers, checking the structure of data
# ...

# %%
col = 'P2S1Q3'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
print(v_count)
# print(cleaned_df[col])

lbls = list(v_count.index)
vals = list(v_count)
fig = go.Figure(data=[go.Pie(labels=lbls, values=vals)])
fig.show()

# print(list(cleaned_df[col]))
# Out:
# **Q3. Do you use any specific tool to test the quality of data?**
# No                                                      36
# Yes                                                      7
# python's pandas, GCP's bigquery                          1
# I write my own tools for this task.                      1
# ELK Kibana                                               1
# Pandas, Numpy, File Formats, Python Standard Library     1
# Name: P2S1Q3, dtype: int64
# <div>
#
#
#             <div id="f74c75dd-939d-4c13-8c7c-b32f6e418db6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f74c75dd-939d-4c13-8c7c-b32f6e418db6")) {
#                     Plotly.newPlot(
#                         'f74c75dd-939d-4c13-8c7c-b32f6e418db6',
# ...

# %%
col = 'P2S1Q4'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(v_count.index)
resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
# Out:
# **Q4. What kind of tools do you use for data cleaning?**
# 1: pandas
# 2: python
# 3: I implement my own solutions.
# 4: Pandas...
# 5: CVAT
# 6: Google Cloud Dataprep and Dataflow.
# 7: Python and internal libraries
# 8: regex, custom code
# 9: Handcrafted tools based on the requirements.
# 10: Python scripts
# 11: Notebooks
# 12: Pandas and basic preprocessing
# 13: Pandas
# 14: Self-developed
# 15: Regular NLP methods
# 16: NLTK - SpaCy
# 17: JAVA, Python, Python NLTK
# 18: python
# visualization
# 19: pandas, numpy, matplotlib, scipy, sklearn
# 20: Pandas, OpenCV (Images), SpaCy (text), various file format handlers etc.
# 21: None. The only cleaning I’ve done is reorganising a dataset I created which was literally done by viewing the image, then dragging and dropping between folders.
# 22: pandas and numpy
# 23: pandas, numpy, jupyter notebook
# 24: None, because we use uncleaned data
# 25: Hand-made python scripts, open-source libraries (nltk, spacy)
# ...

# %%
col = 'P2S1Q5'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(v_count.index)
resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
# Out:
# **Q5. In your opinion, what are the key limitations/challenges of the current data cleaning tools/methods?**
# 1: Datasets bigger than RAM size
# 2: As far as I am concerned, there is no coherent package for that
# 3: most data is noise, tools don't help much to filter it out
# 4: No idea
# 5: large datasets
# 6: Scaling to multi terabytes.
# 7: No standard and versatile tool (also problem itself is not very generic) as it has lots of nuances.
# 8: They are not generalizable to different use cases, like text and images.
# 9: none
# 10: Pandas isn't optimal for data that doesn't fit in memory, and only a subset of the team has Dask experience
# 11: No decisive opinion
# 12: For image data, not much can be done
# 13: Some tasks cannot be automated or rule-based and AI/ML techniques need to be applied to data cleaning itself
# 14: In the medical industry the standards themselves are really bad, so that needs to be changed to allow more growth in this sector.
# 15: Takes lots of memory
# ...

# %%
col = 'P2S1Q6'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(v_count.index)

resp_list = []
resp_set =[]

resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
    resps = resp[i].split(';')
    resp_list.append(resps)
    resp_set.extend(resps)

values = list(cleaned_df[col].values)
# print(type(values))

# print(resp_list)
# print(resp_set)
all_resp = list(set(resp_set))
# print(all_resp)
    
resp_count = []
for i in range (len(all_resp)):
    resp_count.extend([0])

valid = 0
for i in range (len(all_resp)):    
    count = 0
    for j in range(len(values)):
        if str(values[j])!='nan':
            if i == 0:
                valid= valid +1
            if str(all_resp[i]) in str(values[j]).split(';'):
                count =count+1
    resp_count[i]= count

print(resp_count)
print(valid)

data = pd.DataFrame()
data['Data Source'] = all_resp
data['Count'] = resp_count
fig = px.bar(data, x='Data Source', y='Count')
fig.show()
# Out:
# **Q6. Once you have defined/implemented functions for data cleaning and transformation, how do you test the correctness of your code?**
# 1: Manually checking the results for test samples;Debugging the code;Validating results by automated scripts;Visualization of output data;Descriptive statistics or data distribution analysis
# 2: Manually checking the results for test samples;Debugging the code;Visualization of output data
# 3: Manually checking the results for test samples;Validating results by automated scripts;Visualization of output data;Descriptive statistics or data distribution analysis
# 4: Manually checking the results for test samples;Visualization of output data
# 5: Manually checking the results for test samples;Debugging the code;Visualization of output data;Descriptive statistics or data distribution analysis
# 6: Manually checking the results for test samples;Validating results by automated scripts;Visualization of output data
# ...

# %%
col = 'P2S1Q7'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(v_count.index)
resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
# Out:
# **Q7. What are the quality attributes that you consider important for your machine learning dataset(s)?**
# 1: high discrimanation between features
# 2: Consistent with inference data; be relevant for the model; be consisten with itself.
# 3: Balanced data.
# 4: samples well balanced across classes, many meaningful features with high variance, accurately labelled samples
# 5: Good data
# 6: existence of viable features, having enough data with minimum missing values
# 7: Size of the dataset, the number of missed data, the number of outlayers and the structure of the data
# 8: Quantity and correct labels
# 9: Features, Class Balance, Number of Examples etc.
# 10: number of instances, labelled or not, label missing or not,
# 11: 1) Balancing of data of each class
# 2) Looking for outliers and removing them
# 3) Removal of null attributes
# 12: Size, diversity
# ...

# %%
col = 'P2S1Q8'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(v_count.index)
resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
# Out:
# **Q8. For a large volume of training data, how do you test your data quality in terms of class balancing in the dataset?**
# 1: statistics
# 2: struggle with large data will be using Kubernites to check that
# 3: Depends on the effect it has on model.
# 4: check number of positive instances vs. number of negative ones
# 5: Sampling and if is really skewed we use metrics like F1
# 6: Downsampling and upweighting.
# 7: manual analysis.
# 8: extracting the category sizes and manual analysis
# 9: Bar chart
# 10: I work mainly in anomaly detection, so it's a straight forward matter of what proportion of the dataset don't belong to the majority class
# 11: Our datasets are generally imbalanced by nature.
# 12: Use balancing methods
# 13: Usually don't, evaluate sensitivity of the model at the end on generated data
# 14: Statistical analysis using Python scripts
# 15: Randomly sample a portion and calculate the class distribution in it.
# 16: I don't work with large volume of training data
# ...

# %%
col = 'P2S1Q9'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(v_count.index)

resp_list = []
resp_set =[]

resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
    resps = resp[i].split(';')
    resp_list.append(resps)
    resp_set.extend(resps)

values = list(cleaned_df[col].values)
# print(type(values))

# print(resp_list)
# print(resp_set)
all_resp = list(set(resp_set))
# print(all_resp)
    
resp_count = []
for i in range (len(all_resp)):
    resp_count.extend([0])

valid = 0
for i in range (len(all_resp)):    
    count = 0
    for j in range(len(values)):
        if str(values[j])!='nan':
            if i == 0:
                valid= valid +1
            if str(all_resp[i]) in str(values[j]).split(';'):
                count =count+1
    resp_count[i]= count

print(resp_count)
print(valid)

data = pd.DataFrame()
data['Data Labeling'] = all_resp
data['Count'] = resp_count
fig = px.bar(data, x='Data Labeling', y='Count')
fig.show()
# Out:
# **Q9. How do you test the accuracy of your data labeling?**
# 1: Manual Investigation
# 2: Manual Investigation;Automated script/tools
# 3: Automated script/tools
# 4: Manual Investigation;run machine learning algorithms on them to get more information
# 5: Manual Investigation;Inhouse experts.
# 6: Manual Investigation;no specific methods applied
# 7: Manual Investigation;Domain Knowledge
# 8: NLP labeling is subject to interpretation, there is no accuracy to look for. We trust our training process which includes a QA from a domain expert.
# 9: don't
# 10: No labels.
# 11: Run a model with decent performance then see the errors, usually if your model is good enough the error items are mislabeled.
# 12: I do no
# 13: Manual Investigation;Automated script/tools;Automated tools that compares manual annotation to predicted result
# 14: No labels
# 15: Not applicable in my field
# ...

# %%
col = 'P2S1Q10'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(v_count.index)
resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
# Out:
# **Q10. In your opinion, what are the key challenges in labeling data for ML algorithms?**
# 1: Ammount of data
# 2: When using ML algorithms to label data in a feed forward method it is difficult to rely on the predictions when there are false positives in the predictions. Essentially the model might be learning the wrong things. Another Issue is having a limited amount of labelled data, training models on a limited dataset is quite a difficult problem to solve. One possible solution would be to generate labelled data whether it be manually / statistically etc. The challenges are to determine whether one method would generate better results than the done without putting in the time to test and experiment with both options.
# 3: labeling is slow and expensive
# 4: Consistency, being rigorous to your team about whats expected. In the medical industry this is hard because labelling data is expensive.
# 5: Human biases
# ...

# %%
col = 'P2S2Q1'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(v_count.index)
resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
# Out:
# **Q1. What kind of tools do you use for feature engineering?**
# 1: programming languages and frameworks
# 2: pandas, numpy
# 3: Pandas
# 4: Deep neural networks
# 5: normalization, PCA, fourier transform
# 6: XGBoost for feature importance, consultation with domain experts for feature engineering
# 7: For our task of NLP, we used the Sci-Kit Learn libraries of python which consists of count vectorizer and TF-IDF vectorizer which use mathematical methods that analyze the data to extract features and also word embeddings trained on large dataset. For other Machine Learning tasks, I used principal component analysis and other similar approaches which extract only the uncorrelated fields using eigenvalue decomposition.
# 8: Domain knowledge remains my favorite tool, I understand the problem and read the current research to devise the best features.
# 9: pandas, numpy, scipy, nltk, networkx
# 10: none
# 11: Neural network does the feature engineering
# 12: Pandas, Numpy
# 13: Spark, NNs
# ...

# %%
col = 'P2S2Q2'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(v_count.index)
resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
# Out:
# **Q2. In your opinion, what are the key limitations in existing feature engineering methods/tools?**
# 1: No idea
# 2: learning curve
# 3: require too much expert knowledge
# 4: Difficulties with setting specific properties
# 5: User behavior is inherently difficult to encode in any feature space, but it's the domain of interest for much of anomaly detection in cyber security. I'd like to see more industry-ready research in this field
# 6: Not automated enough
# 7: nothing
# 8: none
# 9: They are mainly limited to tasks and types of datasets.
# 10: Every problem is different. Some problems require domain knowledge, that is difficult to translate in a general way to an open-source tool.
# 11: I don't have any answer for this.
# 12: We usually use the representation power for deep learning models. So, we do not specifically select features for models.
# 13: For image data, CNN is the standard method, too many parameters might be the limitation.
# ...

# %%
col = 'P2S2Q3'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(v_count.index)
resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
# Out:
# **Q3. In your opinion, what are the key challenges in feature engineering for machine learning applications?**
# 1: -
# 2: feature search
# 3: knowing how to properly set features to avoid bias and improper outcomes
# 4: --
# 5: It is very hard to validate the feature quality since the document is not always complete, and different toolkits have different normalization methods.
# 6: I don't have any answer for this.
# 7: there are too many approach to be tried, but you still don't get better results.
# 8: Feature engineering should not exist. As soon as you have someone doing this, you're comprising a great deal of potential, and slowing your pipeline down a lot. Waste of money.
# 9: Feature extraction in a fully unsupervised manner
# 10: Incorporating domain knowledge correctly
# 11: Weak exploration of deep networks
# 12: See Q2
# 13: we do this based on domain knowledge
# 14: Same as above.
# 15: The curse of dimensionality, optimization with heuristics
# ...

# %%
col = 'P2S2Q4'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(v_count.index)

resp_list = []
resp_set =[]

resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
    resps = resp[i].split(';')
    resp_list.append(resps)
    resp_set.extend(resps)

values = list(cleaned_df[col].values)
# print(type(values))

# print(resp_list)
# print(resp_set)
all_resp = list(set(resp_set))
# print(all_resp)
    
resp_count = []
for i in range (len(all_resp)):
    resp_count.extend([0])

valid = 0
for i in range (len(all_resp)):    
    count = 0
    for j in range(len(values)):
        if str(values[j])!='nan':
            if i == 0:
                valid= valid +1
            if str(all_resp[i]) in str(values[j]).split(';'):
                count =count+1
    resp_count[i]= count

# print(resp_count)
# print(valid)

data = pd.DataFrame()
data['Feature Selection'] = all_resp
data['Count'] = resp_count
fig = px.bar(data, x='Feature Selection', y='Count')
fig.show()
# Out:
# **Q4. How do you select features for your model from the list of fields in the data?**
# 1: By incrementally adding features;Feature selection is done based on the analysis of data and the data correlation;Features are selected based on the domain knowledge;Using automated feature selection tools or techniques
# 2: Feature selection is done based on the analysis of data and the data correlation;Features are selected based on the domain knowledge
# 3: Features are selected based on the domain knowledge
# 4: Feature selection is done based on the analysis of data and the data correlation;Using automated feature selection tools or techniques
# 5: Features are selected based on the domain knowledge;Using automated feature selection tools or techniques
# 6: By incrementally adding features;Feature selection is done based on the analysis of data and the data correlation;Features are selected based on the domain knowledge
# ...

# %%
col = 'P2S2Q5'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(v_count.index)
resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
# Out:
# **Q5. How do you validate whether your created features represent the characteristics of the dataset?**
# 1: correlation metrics
# 2: In a typical project, I would rely on my good judgment. Would that feature help me, as a human, make a prediction. Since my own capacities are limited, I would use forward/backward selection if I can rapidly train a model.
# 3: Dimensionality Reduction Methods can be helpful here
# 4: Usually we don't care if they are representative as long as the downstream performance is good.
# 5: Using model interpretability/explainabilty (such as LIME, SHAP), or using precision metrics (such as Fscore, accuracy, recall, etc).
# 6: For the NLP tasks, I have used the traditional feature extraction methods and have never looked to validate them.
# 7: By looking at the end capabilities of the network
# 8: Mostly a good enough model justifies the data.
# 9: By running base line algorithms such as Logistic Regression and see how they bare on each set of features
# ...

# %%
col = 'P3S1Q1'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
print(v_count.index)

resp_list = []
resp_set =[]

resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
    resps = resp[i].split(';')
    resp_list.append(resps)
    resp_set.extend(resps)

values = list(cleaned_df[col].values)
# print(type(values))

# print(resp_list)
# print(resp_set)
all_resp = list(set(resp_set))
# print(all_resp)
    
resp_count = []
for i in range (len(all_resp)):
    resp_count.extend([0])

valid = 0
for i in range (len(all_resp)):    
    count = 0
    for j in range(len(values)):
        if str(values[j])!='nan':
            if i == 0:
                valid= valid +1
            if str(all_resp[i]) in str(values[j]).split(';'):
                count =count+1
    resp_count[i]= count

# print(resp_count)
# print(valid)

data = pd.DataFrame()
data['ML Training'] = all_resp
data['Count'] = resp_count
fig = px.bar(data, x='ML Training', y='Count')
fig.show()
# Out:
# **Q1. Do you write your ML training code from scratch or use machine-learning libraries and--or frameworks?**
# Index(['Using ML libraries or frameworks',
#        'From the scratch;Using ML libraries or frameworks', 'From the scratch',
#        'Using ML libraries or frameworks;own autoML system'],
#       dtype='object')
# 1: Using ML libraries or frameworks
# 2: From the scratch;Using ML libraries or frameworks
# 3: From the scratch
# 4: Using ML libraries or frameworks;own autoML system
# <div>
#
#
#             <div id="e714d4a9-da27-4877-add3-c851cdd4f8fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e714d4a9-da27-4877-add3-c851cdd4f8fe")) {
#                     Plotly.newPlot(
#                         'e714d4a9-da27-4877-add3-c851cdd4f8fe',
# ...

# %%
col = 'P3S1Q2'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(v_count.index)
resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
# Out:
# **Q2. If you happen to implement your ML training code from scratch, how do you test your code?**
# 1: accuracy
# 2: against existing frameworks
# 3: check results compared to other methods, observe the prediction
# 4: Check what goes in, goes out. Test it on an established dataset.
# 5: By staring at it
# 6: By monitoring the model parameters and also the model prediction errors
# 7: With a validation set / market experts
# 8: This question is a little confusing... I can test if the neural network architecture definition is correct generating a visualization of architecture using Tensorflow, and check if it's logically correct.
# 9: With a set of dummy data that we know will give a certain results if our codes were implemented properly
# 10: mock up a few examples and expected predictions, also use property based testing the check that the predictions are in certain ranges.
# ...

# %%
col = 'P3S1Q3'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(v_count.index)
resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
# Out:
# **Q3. If you use ML libraries to write custom functions for ML training, how do you test your implementation?**
# 1: accuracy
# 2: By running on classical data sets such Iris or Boston and infer correctness based on the results.
# 3: Metrics, Train/Test Loss curves etc.
# 4: true training/testing split and see how good my prediction stand against the data
# 5: Mainly through measuring the performance on the test dataset, or through cross-validation.
# 6: Visually (that’s all I’ve dealt with)
# 7: Custom tests on proprietary datasets.
# 8: running on own dataset and compare with original
# 9: Same as above.
# 10: I will test it over the test-cases where the outcome is known and also check cross-val score. Testing depends not only on the implementation but also on the data. If data is bad or mislabeled then it's difficult to test and improve it.
# 11: Test on simple crafted data
# 12: For a neural net I try to make it overfit the training set. This way I know it can learn something.
# ...

# %%
col = 'P3S1Q4'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(v_count.index)
resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
# Out:
# **Q4. What software testing techniques or frameworks (if any) do you use for machine learning application testing?**
# 1: pytest
# 2: Not Applicable
# 3: None
# 4: none
# 5: unit testing
# 6: Gerkin
# 7: Manual
# 8: Nothing in specific comes to my mind.
# 9: Self-written
# 10: nosetests
# 11: unit testing, integration testing
# 12: None. I’ve only worked with images so I test the output manually.
# 13: non
# 14: I have used boost unit test libraries for writing testing code for the machine libraries of MLPack which were in C++. Otherwise, in python I generally look for write some test cases and check if the corresponding output is correct at every step.
# 15: Tensorflow
# 16: My own written tests over the given test set
# 17: There are many methods which can be implemented, having a criteria which must be met in terms of accuracy and results for users on the platform which you are willing to accept to move forward.
# ...

# %%
col = 'P3S1Q5'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(v_count.index)
resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
# Out:
# **Q5. Which symptoms do you believe indicates the presence of defects in an ML code implementation?**
# 1: low accuracy
# 2: very high variance (overfitting) or high bias with respect to the labels
# 3: Biases, edge cases
# 4: not sure
# 5: no idea, tbh
# 6: -
# 7: nondeterminisitic results (given correct seeding)
# 8: unknown
# 9: I don't have any answer for this.
# 10: Inconsistency of results, over-sensitivity
# 11: NaN, non convergence, errors
# 12: Accuracy too high, Accuracy too low, model is not able to overfit the data, inference time take ages, the accuracy is lower than guessing/baseline model
# 13: Owerfitting, underfitting
# 14: simulation failure, learning rate plateau
# 15: When the ML implementation does not converge when training the model; when I use some visualization tool to generate the neural network architecture and I see blocks not connected together.
# 16: Wrong output, limited possibilities to generalize
# ...

# %%
col = 'P3S1Q6'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(v_count.index)
resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
# Out:
# **Q6. Which tools (if any) do you use to verify the presence of bugs or defects?**
# 1: None
# 2: metric validation
# 3: None.
# 4: nothing
# 5: Github ?
# 6: Pytorch
# 7: none
# 8: unit-tests and integration tests
# 9: unknown
# 10: sklearn, tensorflow, keras, pytorch
# 11: AWS elastic dashboard
# 12: Nothing in specific comes to my mind.
# 13: pdb with python or simply a PrintLayer if I am using pytorch.
# 14: Tensorflow
# 15: debugget
# 16: Manual tests, visualizations
# 17: I have not used any specific tools apart from the bugs shown on the IDE that I use.
# 18: no specific tools applied
# 19: I do not use any particular tool
# 20: PyCharm IDE
# 21: typical software engineering tools used for unit testing, etc
# 22: Simply logging them and debugging
# 23: Continuous integration (unittest, Docker, Pipenv, GitLab CI)
# 24: not applicable
# 25: Unit tests
# 26: Pytorch, tensorboard
# 27: test automation
# ...

# %%
col = 'P3S1Q7'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(v_count.index)
resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
# Out:
# **Q7. Do you review the code of ML applications in your organization? If yes, which approach do you follow and which tools do you use when performing these code reviews?**
# 1: No
# 2: Merge requests plus code review
# 3: Yes, Github
# 4: Proprietary tools.
# 5: yes, typical tools used for reviews such a pull requests on GitHub
# 6: Yes, we use github's built in code review tool.
# 7: no
# 8: GitLab
# 9: Before merging code, we conduct a code review.
# 10: Mostly github to review the logic of the code, and running tests for Quality
# 11: not applicable
# 12: Pull requests with code review
# 13: yes within the AI team
# 14: I just look at the code and run my internal brain compiler on it. It works. I don't use tools. Machine learning code is just like any other code. It should be modular  and extensible and the like. If the model performs well on the test set / it's fast / etc, it should be ok.
# 15: yes
# 16: Yes
# 17: No, I'm not review the code of others.
# ...

# %%
col = 'P3S1Q8'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(v_count.index)
resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
# Out:
# **Q8. In your opinion, what are the key challenges in reviewing the code of ML applications?**
# 1: black box nature
# 2: -
# 3: poor documentation
# 4: Hard to know what corners you can cut
# 5: code reviews are too rare
# 6: Correctness of algorithm is often hard to check.
# 7: Usually we review style, no core understanding of algorithm itself as ML engineers work in isolation and do not provide enough architecture detail.
# 8: Checking the code for correctness in the absence of ready-made tests
# 9: time and budget
# 10: Complexity in mathematical background of the code
# 11: testing the accuracy of any amount of code requires huge amounts of data, thus there is a need to figure out how to manage that data
# 12: Lack of official implementations.
# 13: Explaining and understanding what the code should do
# 14: Notebooks and github friendly
# 15: Needs domain expertise
# 16: (unsure about the answer) people have different coding style
# ...

# %%
col = 'P3S2Q1'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(v_count.index)

resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
# Out:
# **Q1. Do you conduct testing of ML models in your organization? if yes, please briefly describe your testing strategies.**
# 1: No
# 2: accuracy validation
# 3: Calculation of quality indicators on sufficiently studied datasets
# 4: Yes, black-box testing first then white-box testing.
# 5: no
# 6: Already answered
# 7: looking at the accuracy of the model or success of our recommendations
# 8: deployment and manual monitoring
# 9: Yes, model dependent.
# 10: -
# 11: No idea
# 12: Not applicable
# 13: Split data into training-validation-testing parts.
# 14: mocking up examples and property based tests
# 15: solely performance on train/test split
# 16: randomized code review
# mandatory code testing
# 17: I know people using A/B testing; I follow the train-validate-test data split and do 10-fold cross-validation.
# 18: By writing execution tests over a test set with given ground truth
# ...

# %%
col = 'P3S2Q2'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(v_count.index)
resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
# Out:
# **Q2. What metrics do you use to assess the performance of ML models?**
# 1: precision, recall, f1, accuracy
# 2: same metrics as used for the testing phase during training (F1, etc)
# 3: mean squared error, mean absolute error, r-squared, accuracy, f1-score, precision, recall
# 4: Depends upon the problem statement. It can be just accuracy, roc-auc, precision, recall or f1-score.
# 5: Specific to each task
# 6: accuracy, f1-score, precision, recall, mean absolute percentage error, mean squared error
# 7: performance in the real world
# 8: -
# 9: F1 Score, Accuracy.
# 10: all manual
# 11: yes
# 12: Accuracy, AUC-ROC, Classwise Precision and Recall etc.
# 13: Confusion matrix, AUC, P@K, F1-Score...
# 14: reward
# 15: Precision, Recal, F1-score, Accuracy, NDCG, RMSE.
# 16: Runtime / accuracy
# 17: MCC, classic binary metrics
# 18: Accuracy based and Exception based
# 19: F1 Score or accuracy
# 20: Collecting validation set independently.
# ...

# %%
col = 'P3S2Q3'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
print(v_count)
# Out:
# **Q3. How often do you rely on black box (without knowing the internal structure or implementation) testing of ML models using test data sets?**
# 4.0    18
# 1.0    10
# 2.0     8
# 3.0     5
# 5.0     2
# Name: P3S2Q3, dtype: int64

# %%
col = 'P3S2Q4'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
print(v_count)
# Out:
# **Q4. How often do you use white box (knowing the internal structure and implementation) testing techniques for your ML models?**
# 4.0    12
# 3.0    12
# 2.0     9
# 5.0     8
# 1.0     2
# Name: P3S2Q4, dtype: int64

# %%
col = 'P3S2Q5'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
print(v_count)
# Out:
# **Q5. Do you leverage generative models or other techniques to generate synthetic data and identify adversarial examples for testing?**
# 1.0    16
# 2.0    11
# 3.0    10
# 4.0     5
# 5.0     1
# Name: P3S2Q5, dtype: int64

# %%
col = 'P3S2Q6'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(v_count.index)
resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
# Out:
# **Q6. What are the key challenges you have experienced when ensuring the correctness of your ML models?**
# 1: black box nature
# 2: Having a bad model due to bad data: makes it very difficult to detect and expensive to solve.
# 3: Gradient inspection. It would be awesome some kind of software or library that checks your gradients and tell if there is something strange.
# 4: In the medical industry data bias is hard to get over, and typically requires vast amounts of augmentation.
# 5: A wrong implementation sometimes achieves similar performance, and the bug cannot be found until we introduce new features.
# 6: lack of domain knowledge
# 7: The model is wrong, but the result is not
# 8: That's usually a data problem; how well does the data available during training reflect true operational data, and how long until the nature of the operational data diverges from your original data and assumptions
# 9: To represent the real distributions faithfully.
# 10: Biases
# ...

# %%
col = 'P3S3Q1'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(v_count.index)

resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
# Out:
# **Q1. Which deployment strategies (e.g., services, platform architecture, etc.)  are adopted in your organization for ML models?**
# 1: self-host
# 2: None
# 3: none
# 4: serverless and flask API
# 5: I don't deploy
# 6: Spark, hadoop.
# 7: gitlab packaging, platform architecture
# 8: we develop in house tools for deployment
# 9: Flask
# 10: not clear
# 11: Tensorflow-serving
# 12: Deploy on cloud server running Ubuntu.
# 13: Caffe, Inception V3, YOLO, Tensorflow (Keras).
# 14: We just use linux based desktop systems
# 15: Azure, kubernetes, docker
# 16: Nothing specific
# 17: OpenVINO
# 18: Monthly releases, weekly training io models.
# 19: services
# 20: Azure ML
# 21: Not Applicable
# 22: Arduino, embedded systems, PC, mobile phone using TensorFlow Lite
# 23: Distributed workers.
# 24: no specific approach applied
# 25: LSTM, DFNN, IBM Watson
# 26: Confidential
# 27: cloud platform
# 28: Google Cloud Services
# 29: we mainly deploy in GCP
# 30: HTTP-servers, Amazon cloud servers
# ...

# %% [markdown]
# col = 'P3S3Q2'
# printmd('**'+ques_dict[col]+'**')
# print()
#
# v_count = cleaned_df[col].value_counts()
# print(v_count.index)
# resp = list (v_count.index)
# for i in range (len(resp)):
#     print('{}: {}'.format((i+1), resp[i]))

# %%
col = 'P3S3Q3'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(v_count.index)
resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
# Out:
# **Q3. Do you perform post deployment testing of ML applications?**
# 1: Yes
# 2: No
# 3: no
# 4: yes
# 5: With a manuall test. I choose some random examples collected from real-world data, create the labels and compare with outputs of the ML.
# 6: Typically gauge reactions from users, report & fix bugs that users identify
# 7: All is continually monitored
# 8: No.
# 9: We do QA at the end
# 10: Yes, online learning and testing
# 11: not unless issues are encountered during production
# 12: Not yet in production
# 13: Test it in real-time
# 14: unknown
# 15: Yes. By real usage.
# 16: i don't
# 17: Not Applicable
# 18: Yes. Regression unit tests
# 19: no specific approach applied
# 20: not done that yet
# ...

# %%
col = 'P3S3Q4'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
print(v_count)
# Out:
# **Q4. How often do you monitor model performance of your ML model after deployment?**
# 3.0    15
# 5.0    12
# 1.0     6
# 4.0     4
# 2.0     3
# Name: P3S3Q4, dtype: int64

# %%
col = 'P3S3Q5'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(v_count.index)
resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
# Out:
# **Q5. What are the key performance parameters that you monitor at the post-deployment phase of your ML models?**
# 1: Inference time
# 2: Mainly the same as during training and validation
# 3: unknown
# 4: Changing in accuracy
# 5: Performance
# 6: We mainly work individually in our team, so we do not have the deployment phase per se.
# 7: Human review
# 8: MAPE, RMSE
# 9: -
# 10: no specific performance parametersapplied
# 11: correctness and speed
# 12: reward, action variability, difficulty performance
# 13: reliability and validity
# 14: Mostly speed and edge cases
# 15: In general, Accuracy and NDCG.
# 16: Inference time, CPU/GPU/memory/power usage, prediction similar to development model
# 17: Accuracy
# 18: Run time cost + output matches with previous code version
# 19: Latency for predictions,  accuracy.
# 20: No idea
# 21: usually end-user perspective, so justification and explainability
# 22: Distribution of income (anonymous), outcome (anonymous)
# ...

# %%
col = 'P3S3Q6'
printmd('**'+ques_dict[col]+'**')
print()

v_count = cleaned_df[col].value_counts()
# print(v_count.index)
resp = list (v_count.index)
for i in range (len(resp)):
    print('{}: {}'.format((i+1), resp[i]))
# Out:
# **Q6. In your opinion, what are the key challenges in assessing the correctness of the deployment of  ML models?**
# 1: -
# 2: interpretability
# 3: keeping track of predictions
# 4: obtaining correctly labelled data, as expected
# 5: Lack of ground truth for real life new data
# 6: none
# 7: Labeling data
# 8: Question not clear
# 9: Assessing the accuracy is not hard but It's hard to measure resource usage in mobile phone. It's difficult because in the phone we don't have the same libraries and tools we can use to develop like on PC.
# 10: The most appropriate result metrics may or may not be understood by all the teams.
# e.g. Accuracy they understand and F1Score is what matters.
# 11: No data
# 12: Due the model complexity, it is hard to understand where the problem is from
# 13: The errors may be introduced by some feature extraction and preprocessing libraries like OpenCV and nltk. They may have different behaviors on different platforms.
# ...
